# %%
# !pip install marshmallow
# Out:
# ...
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install pymongo
# Out:
# ...
#    ---------------------------------------- 0.0/831.6 kB ? eta -:--:--
#    ------------------------- -------------- 524.3/831.6 kB 2.8 MB/s eta 0:00:01
#    ---------------------------------------- 831.6/831.6 kB 2.6 MB/s eta 0:00:00
# ...
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from pymongo.mongo_client import MongoClient
from flask import Flask, request, jsonify
from pymongo import MongoClient
from marshmallow import Schema, fields, ValidationError

# %%
client = MongoClient("mongodb+srv://stark:Murali123@cluster0.qq2ou.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0")
db = client['USER_DATA']
collection = db['user_profile']

# %%
try:
    client.admin.command('ping')
    print("You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# You successfully connected to MongoDB!

# %%
class EmployerSchema(Schema):
    name = fields.Str(required=True)
    type = fields.Str(required=True)

class AddressSchema(Schema):
    city = fields.Str(required=True)
    zip_code = fields.Str(required=True)
    country = fields.Str(required=True)

class CustomerSchema(Schema):
    customer_id = fields.Str(required=True)
    full_name = fields.Str(required=True)
    dob = fields.Str(required=True)
    gender = fields.Str(required=True)
    marital_status = fields.Str(required=True)
    nationality = fields.Str(required=True)
    occupation = fields.Str(required=True)
    industry = fields.Str(required=True)
    education_level = fields.Str(required=True)
    employer = fields.Nested(EmployerSchema, required=True)
    annual_income_bracket = fields.Str(required=True)
    dependents_count = fields.Int(required=True)
    address = fields.Nested(AddressSchema, required=True)
    phone_number = fields.Str(required=True)
    email = fields.Str(required=True)

class RelationshipInsightsSchema(Schema):
    spouse = fields.Dict(keys=fields.Str(), values=fields.Str())
    children = fields.List(fields.Str())
    linked_accounts = fields.List(fields.Str())

class FinancialTransactionSchema(Schema):
    type = fields.Str(required=True)
    amount = fields.Float(required=True)
    date = fields.Str(required=True)

class FinancialTransactionsSchema(Schema):
    deposits_withdrawals = fields.List(fields.Nested(FinancialTransactionSchema))
    spending_categories = fields.Dict(keys=fields.Str(), values=fields.List(fields.Float()))
    bill_payments = fields.Dict(keys=fields.Str(), values=fields.List(fields.Float()))

class LoanSchema(Schema):
    type = fields.Str(required=True)
    amount = fields.Float(required=True)
    emi = fields.Float(required=True)
    status = fields.Str(required=True)

class CreditCardSchema(Schema):
    type = fields.Str(required=True)
    limit = fields.Float(required=True)
    usage = fields.List(fields.Float())
    due_date = fields.Str(required=True)
    late_payments = fields.Int(required=True)

class BankingProductsSchema(Schema):
    accounts = fields.Dict(keys=fields.Str(), values=fields.Bool())
    loans = fields.List(fields.Nested(LoanSchema))
    credit_cards = fields.List(fields.Nested(CreditCardSchema))
    investments = fields.Dict(keys=fields.Str(), values=fields.List(fields.Float()))
    insurance = fields.Dict(keys=fields.Str(), values=fields.Bool())

class DigitalBankingSchema(Schema):
    preferred_channels = fields.List(fields.Dict())

class CustomerDataSchema(Schema):
    Customer = fields.Nested(CustomerSchema, required=True)
    RelationshipInsights = fields.Nested(RelationshipInsightsSchema, required=True)
    FinancialTransactions = fields.Nested(FinancialTransactionsSchema, required=True)
    BankingProducts = fields.Nested(BankingProductsSchema, required=True)
    DigitalBanking = fields.Nested(DigitalBankingSchema, required=True)

# %%
schema = CustomerDataSchema()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 schema = CustomerDataSchema()
#
# NameError: name 'CustomerDataSchema' is not defined

# %%
def post_document(data):
  document_data = schema.load(data)
  result = collection.insert_one(document_data)
  return

# %%
data = {
    "Customer": {
      "customer_id": "001",
      "full_name": "Rahul Sharma",
      "dob": "1998-06-15",
      "gender": "Male",
      "marital_status": "Married",
      "nationality": "Indian",
      "occupation": "Software Engineer",
      "industry": "Information Technology",
      "education_level": "Bachelor's Degree",
      "employer": {
        "name": "Tech Solutions Pvt Ltd",
        "type": "Private"
      },
      "annual_income_bracket": "6-10 LPA",
      "dependents_count": 1,
      "address": {
        "city": "Bangalore",
        "zip_code": "560001",
        "country": "India"
      },
      "phone_number": "+91-9876543210",
      "email": "rahul.sharma@email.com"
    },
    "RelationshipInsights": {
      "spouse": {
        "name": "Priya Sharma",
        "customer_id": "002"
      },
      "children": [],
      "linked_accounts": ["002"]
    },
    "FinancialTransactions": {
      "deposits_withdrawals": [
        {
          "type": "Salary Credit",
          "amount": 75000,
          "date": "2025-03-01"
        },
        {
          "type": "UPI Payment",
          "amount": -2000,
          "date": "2025-03-10"
        },
        {
          "type": "Online Shopping",
          "amount": -5000,
          "date": "2025-03-15"
        },
        {
          "type": "Salary Credit",
          "amount": 75000,
          "date": "2025-02-01"
        },
        {
          "type": "Dining",
          "amount": -3500,
          "date": "2025-02-12"
        },
        {
          "type": "Grocery",
          "amount": -7000,
          "date": "2025-02-20"
        },
        {
          "type": "Salary Credit",
          "amount": 75000,
          "date": "2025-01-01"
        },
        {
          "type": "Fuel",
          "amount": -6000,
          "date": "2025-01-15"
        },
        {
          "type": "Insurance Payment",
          "amount": -8000,
          "date": "2025-01-25"
        }
      ],
      "spending_categories": {
        "grocery": [7000, 6500, 6000],
        "dining": [3500, 4000, 4500],
        "travel_fuel": [6000, 7500, 8000],
        "entertainment": [3000, 2800, 3200],
        "shopping": [5000, 7000, 8500],
        "healthcare": [2500, 3000, 2700],
        "education": [1500, 1600, 1400]
      },
      "bill_payments": {
        "utilities": [2000, 2100, 2200],
        "internet": [1200, 1200, 1200],
        "subscriptions": [800, 850, 900]
      }
    },
    "BankingProducts": {
      "accounts": {
        "Savings Account": True,
        "Current Account": False,
        "Salary Account": True,
        "Fixed Deposit": False,
        "Recurring Deposit": False
      },
      "loans": [
        {
          "type": "Auto Loan",
          "amount": 500000,
          "emi": 12000,
          "status": "Active"
        }
      ],
      "credit_cards": [
        {
          "type": "Basic Credit Card",
          "limit": 200000,
          "usage": [45000, 50000, 48000],
          "due_date": "2025-03-25",
          "late_payments": 0
        }
      ],
      "investments": {
        "Mutual Funds": [],
        "Stock Trading Account": [],
        "retirement_savings": [45000]
      },
      "insurance": {
        "Life Insurance": False,
        "Health Insurance": True,
        "Motor Insurance": True,
        "Travel Insurance": False
      }
    },
    "DigitalBanking": {
      "preferred_channels": ["Mobile Banking", "UPI", "Internet Banking"]
    }
  }

# %%
post_document(data)

# %%
# !pip install faker
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 19.8 MB/s eta 0:00:00
# ...

# %%
import random
from faker import Faker
import json

fake = Faker()
Faker.seed(42)
random.seed(42)

# %%
def generate_mock_data(n=30):
    samples = []
    genders = ["Male", "Female"] * (n // 2)

    banking_products = {
        "accounts": ["Savings Account", "Fixed Deposit", "Recurring Deposit"],
        "loans": ["Home Loan", "Personal Loan", "Gold Loan", "Loan Against Fixed Deposits"],
        "credit_cards": ["Rewards Credit Card", "Cashback Credit Card", "Secured Credit Card"],
    }

    for i in range(n):
        gender = genders[i]
        full_name = fake.name_male() if gender == "Male" else fake.name_female()

        customer_id = str(700 + i)  # Unique IDs for retirees
        dob = fake.date_of_birth(minimum_age=60, maximum_age=75).isoformat()
        marital_status = "Married" if random.random() < 0.8 else "Widowed"  # 80% Married
        nationality = "Indian"

        dependents_count = random.randint(1, 3) if marital_status == "Married" else random.randint(0, 2)
        address = {"city": fake.city(), "zip_code": fake.zipcode(), "country": "India"}
        phone_number = fake.phone_number()
        email = fake.email()

        linked_accounts = []
        spouse = {}
        if marital_status == "Married":
            spouse_id = str(1100 + i)
            linked_accounts.append(spouse_id)
            spouse = {"name": fake.name_female() if gender == "Male" else fake.name_male(), "customer_id": spouse_id}

        # Financial Transactions with Pension instead of Salary
        financial_transactions = {
            "deposits_withdrawals": [
                {"type": "Pension Credit", "amount": random.randint(30000, 100000), "date": fake.date_this_year().isoformat()},
                {"type": "ATM Withdrawal", "amount": -random.randint(1000, 10000), "date": fake.date_this_year().isoformat()},
                {"type": "Medical Expenses", "amount": -random.randint(5000, 25000), "date": fake.date_this_year().isoformat()},
                {"type": "Insurance Premium", "amount": -random.randint(10000, 50000), "date": fake.date_this_year().isoformat()}
            ],
            "spending_categories": {
                "grocery": [random.randint(5000, 10000) for _ in range(3)],
                "medical": [random.randint(10000, 30000) for _ in range(3)],
                "travel_fuel": [random.randint(5000, 20000) for _ in range(3)],
                "leisure": [random.randint(5000, 15000) for _ in range(3)]
            },
            "bill_payments": {
                "utilities": [random.randint(2000, 5000) for _ in range(3)],
                "subscriptions": [random.randint(500, 2000) for _ in range(3)]
            }
        }

        # Lower probability of loans for retirees
        loans = []
        if random.random() < 0.3:  # 30% chance of having a loan
            loans.append({
                "type": random.choice(banking_products["loans"]),
                "amount": random.randint(100000, 1000000),
                "emi": random.randint(5000, 30000),
                "status": "Active"
            })

        # Lower credit card limits
        credit_cards = []
        if random.random() < 0.6:  # 60% chance of having a credit card
            credit_cards.append({
                "type": random.choice(banking_products["credit_cards"]),
                "limit": random.randint(100000, 500000),
                "usage": [random.randint(20000, 100000) for _ in range(3)],
                "due_date": fake.date_this_year().isoformat(),
                "late_payments": random.randint(0, 2)
            })

        # Increased investments & insurance
        insurance = {
            "Life Insurance": True,
            "Health Insurance": True,
            "Motor Insurance": random.choice([True, False]),
            "Travel Insurance": random.choice([True, False])
        }

        investments = {
            "Mutual Funds": [random.randint(50000, 1000000) for _ in range(random.randint(1, 4))],
            "Fixed Deposits": [random.randint(100000, 500000) for _ in range(random.randint(1, 3))],
            "Stock Trading Account": []
        }

        data = {
            "Customer": {
                "customer_id": customer_id,
                "full_name": full_name,
                "dob": dob,
                "gender": gender,
                "marital_status": marital_status,
                "nationality": nationality,
                "occupation": "Retired",  # Default Value
                "industry": "N/A",  # Default Value
                "education_level": "High School",  # Default Value
                "employer": {"name": "N/A", "type": "N/A"},  # Default Value
                "annual_income_bracket": "5-10 LPA",  # Default Value
                "dependents_count": dependents_count,
                "address": address,
                "phone_number": phone_number,
                "email": email
            },
            "RelationshipInsights": {
                "spouse": spouse,
                "children": [],
                "linked_accounts": linked_accounts
            },
            "FinancialTransactions": financial_transactions,
            "BankingProducts": {
                "accounts": {acc: random.choice([True, False]) for acc in banking_products["accounts"]},
                "loans": loans,
                "credit_cards": credit_cards,
                "investments": investments,
                "insurance": insurance
            },
            "DigitalBanking": {
                "preferred_channels": random.sample(["Mobile Banking", "UPI", "Internet Banking"], k=2)
            }
        }

        samples.append(data)
        post_document(data)  # Assuming `post_document` inserts into MongoDB
    return samples

# %%
generate_mock_data()
# Out:
# [{'Customer': {'customer_id': '700',
#    'full_name': 'Matthew Ryan',
#    'dob': '1964-11-22',
#    'gender': 'Male',
#    'marital_status': 'Married',
#    'nationality': 'Indian',
#    'occupation': 'Retired',
#    'industry': 'N/A',
#    'education_level': 'High School',
#    'employer': {'name': 'N/A', 'type': 'N/A'},
#    'annual_income_bracket': '5-10 LPA',
#    'dependents_count': 3,
#    'address': {'city': 'Michaelhaven',
#     'zip_code': '64397',
#     'country': 'India'},
#    'phone_number': '001-371-369-4722x56996',
#    'email': 'matthewedwards@example.net'},
#   'RelationshipInsights': {'spouse': {'name': 'Debra Newman',
#     'customer_id': '1100'},
#    'children': [],
#    'linked_accounts': ['1100']},
#   'FinancialTransactions': {'deposits_withdrawals': [{'type': 'Pension Credit',
#      'amount': 70959,
#      'date': '2025-01-22'},
#     {'type': 'ATM Withdrawal', 'amount': -1864, 'date': '2025-02-06'},
# ...

# %%
# Fetch the last 20 inserted documents
last_20_docs = list(collection.find().sort([("_id", -1)]).limit(20))

# Extract their IDs
last_20_ids = [doc["Customer"]["customer_id"] for doc in last_20_docs]

last_20_ids
# Out:
# ['519',
#  '518',
#  '517',
#  '516',
#  '515',
#  '514',
#  '513',
#  '512',
#  '511',
#  '510',
#  '509',
#  '508',
#  '507',
#  '506',
#  '505',
#  '504',
#  '503',
#  '502',
#  '501',
#  '500']

# %%
# Fetch all customers
customers = list(collection.find({}, {"Customer.customer_id": 1, "RelationshipInsights": 1, "_id": 0}))

# Dictionary to track families
family_map = {}

# Process each customer
for customer in customers:
    cust_id = customer["Customer"]["customer_id"]
    linked_accounts = set(customer["RelationshipInsights"].get("linked_accounts", []))

    # Ensure the customer is included in their own family set
    linked_accounts.add(cust_id)

    # Check if any existing family already contains these members
    matched_family = None
    for family_id, members in family_map.items():
        if linked_accounts & members:  # If there's an intersection, it's the same family
            matched_family = family_id
            break

    if matched_family:
        # Merge into the existing family
        family_map[matched_family] |= linked_accounts
    else:
        # Create a new family entry
        family_map[cust_id] = linked_accounts

# Print family details
print("Total Families:", len(family_map))
for family_members in family_map.values():
    print(", ".join(sorted(family_members)))  # Print sorted customer IDs in each family
# Out:
# Total Families: 85
# 001, 101
# 100, 103
# 102, 105
# 104, 107
# 106, 109
# 108, 208
# 110
# 111
# 112, 212
# 113, 213
# 114
# 115, 215
# 116
# 117, 217
# 118
# 119, 219, 319
# 300
# 301
# 302
# 303
# 204, 304
# 305
# 206, 306
# 307
# 308
# 309
# 310
# 311
# 312
# 313
# 314
# 315
# 316
# 317
# 318
# 500, 600, 900
# 501, 601
# 502, 602, 902
# 503, 903
# 504, 604, 904
# 505, 605, 905
# 506, 606, 906
# 507, 907
# 508, 608
# 509, 609
# 510, 610
# 511, 611
# 512, 612
# 513, 613
# 514, 614
# 515, 615
# 516
# 517, 617
# 518, 618
# 519, 619
# 1100, 700
# 1101, 701
# 1102, 702
# 1103, 703
# 1104, 704
# 705
# 1106, 706
# 707
# 1108, 708
# 1109, 709
# 1110, 710
# 1111, 711
# 1112, 712
# 1113, 713
# 1114, 714
# 715
# 1116, 716
# 1117, 717
# 1118, 718
# 1119, 719
# 1120, 720
# 721
# 1122, 722
# 723
# 1124, 724
# 1125, 725
# 1126, 726
# 1127, 727
# 728
# 1129, 729
